# %%
import unicodedata
import os
import re
from tqdm import tqdm
from collections import Counter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
BASE_DIR = '/content/drive/MyDrive/проект'

# %% [markdown]
# # Stage 2 (NFC -> NFD)

# %%
def convert_to_nfd_force(files_map, base_dir=BASE_DIR):
    """
    Принудительная конвертация содержимого файлов в NFD.
    Разлагает составные символы (например, 'й' -> 'и' + '̆').
    """
    for input_file, output_file in files_map.items():
        input_path = os.path.join(base_dir, input_file)
        output_path = os.path.join(base_dir, output_file)

        if not os.path.exists(input_path):
            print(f"Файл не найден: {input_path}")
            continue

        with open(input_path, 'r', encoding='utf-8') as f_in:
            content = f_in.read()

        nfd_content = unicodedata.normalize('NFD', content)

        with open(output_path, 'w', encoding='utf-8') as f_out:
            f_out.write(nfd_content)

        print(f"NFD конвертация завершена: {input_file} -> {output_file}")

# %%
tasks = {
    '1_Adyghe_OCR.txt': '2_Adyghe_OCR.txt',
    '1_Adyghe_NoOCR.txt': '2_Adyghe_NoOCR.txt',

    '1_Kabardian_OCR.txt': '2_Kabardian_OCR.txt',
    '1_Kabardian_NoOCR.txt': '2_Kabardian_NoOCR.txt',
}
convert_to_nfd_force(tasks)
# Out:
# NFD конвертация завершена: 1_Adyghe_OCR.txt -> 2_Adyghe_OCR.txt
# NFD конвертация завершена: 1_Adyghe_NoOCR.txt -> 2_Adyghe_NoOCR.txt
# NFD конвертация завершена: 1_Kabardian_OCR.txt -> 2_Kabardian_OCR.txt
# NFD конвертация завершена: 1_Kabardian_NoOCR.txt -> 2_Kabardian_NoOCR.txt

# %% [markdown]
# # Stage 3

# %% [markdown]
# ## Проверка на римские цифры

# %%
import os
import re

# Валидные римские числа 1-3999 (латиница)
ROMAN_LATIN = (
    r'M{0,4}'
    r'(?:CM|CD|D?C{0,3})'
    r'(?:XC|XL|L?X{0,3})'
    r'(?:IX|IV|V?I{0,3})'
)

# То же самое но кириллическими омонимами (І=I, Х=X, С=C, М=M)
ROMAN_CYR = (
    r'[МMмm]{0,4}'
    r'(?:[СCсc][МMмm]|[СCсc][Dd]|[Dd]?[СCсc]{0,3})'
    r'(?:[ХXхxΧχ][СCсc]|[ХXхxΧχ][Ll]|[Ll]?[ХXхxΧχ]{0,3})'
    r'(?:[ІIӀіiӏΙι][ХXхxΧχ]|[ІIӀіiӏΙι][Vv]|[Vv]?[ІIӀіiӏΙι]{0,3})'
)

STANDALONE_STICKS = r'[ӀІӏі]'

roman_pattern = re.compile(
    rf'(?:(?<=[\s\-\–\—\.\,\;\:\!\?\(\[\<\«\"\'\/])|(?<=^))(?:{ROMAN_CYR}|{ROMAN_LATIN}|{STANDALONE_STICKS}|[ⅠⅡⅢⅣⅤⅥⅦⅧⅨⅩⅪⅫⅬⅭⅮⅯ]+)(?=[\s\-\–\—\.\,\;\:\!\?\)\]\>\»\"\'\/]|$)',
    re.UNICODE | re.MULTILINE
)

latin_upper = set("IVXLCDM")
latin_lower = set("ivxlcdm")
cyr_upper = set("ІХСМӀΙΧ")
cyr_lower = set("іхсмӏιχ")
roman_unicode_upper = set("ⅠⅡⅢⅣⅤⅥⅦⅧⅨⅩⅪⅫⅬⅭⅮⅯ")
roman_unicode_lower = set("ⅰⅱⅲⅳⅴⅵⅶⅷⅸⅹⅺⅻⅼⅽⅾⅿ")

def analyze_file(input_file, output_file, base_dir=BASE_DIR):
    """Анализ римских цифр в файле с расширенной классификацией"""

    stats = {
        "latin_only": {},
        "latin_lower": {},
        "cyr_only": {},
        "cyr_lower": {},
        "unicode_roman_upper": {},
        "unicode_roman_lower": {},
        "latin_cyr": {},
        "latin_roman": {},
        "cyr_roman": {},
        "latin_cyr_roman": {}
    }

    input_path = os.path.join(base_dir, input_file)
    output_path = os.path.join(base_dir, output_file)

    if not os.path.exists(input_path):
        print(f"Нет такого файла: {input_path}")
        return

    with open(input_path, 'r', encoding='utf-8') as f:
        text = f.read()

    matches = roman_pattern.findall(text)

    for word in matches:
        has_latin_upper = any(ch in latin_upper for ch in word)
        has_latin_lower = any(ch in latin_lower for ch in word)
        has_cyr_upper = any(ch in cyr_upper for ch in word)
        has_cyr_lower = any(ch in cyr_lower for ch in word)
        has_rom_upper = any(ch in roman_unicode_upper for ch in word)
        has_rom_lower = any(ch in roman_unicode_lower for ch in word)

        has_latin = has_latin_upper or has_latin_lower
        has_cyr = has_cyr_upper or has_cyr_lower
        has_rom = has_rom_upper or has_rom_lower

        # классификация
        if has_latin and not has_cyr and not has_rom:
            if has_latin_lower:
                category = "latin_lower"
            else:
                category = "latin_only"
        elif has_cyr and not has_latin and not has_rom:
            if has_cyr_lower:
                category = "cyr_lower"
            else:
                category = "cyr_only"
        elif has_rom and not has_latin and not has_cyr:
            if has_rom_lower:
                category = "unicode_roman_lower"
            else:
                category = "unicode_roman_upper"
        elif has_latin and has_cyr and not has_rom:
            category = "latin_cyr"
        elif has_latin and has_rom and not has_cyr:
            category = "latin_roman"
        elif has_cyr and has_rom and not has_latin:
            category = "cyr_roman"
        elif has_latin and has_cyr and has_rom:
            category = "latin_cyr_roman"
        else:
            continue

        stats[category][word] = stats[category].get(word, 0) + 1

    # подсчет общей статистики
    totals = {k: sum(v.values()) for k, v in stats.items()}
    total_all = sum(totals.values())

    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(f"Файл: {input_file}\n\n")
        f.write("СТАТИСТИКА\n")
        f.write("-" * 50 + "\n")
        for k, v in totals.items():
            pct = v / total_all * 100 if total_all > 0 else 0
            f.write(f"{k}: {v} ({pct:.5f}%)\n")
        f.write("\n")

        for cat, words in stats.items():
            f.write(f"{cat.upper()}\n")
            f.write("-" * 50 + "\n")
            for w, c in words.items():
                f.write(f"{w} : {c}\n")
            f.write("\n")

    print(f"Анализ сохранён: {output_file}")

# %%
analyze_file('2_Adyghe_OCR.txt', 'roman_stats_3_Adyghe_OCR.txt')
analyze_file('2_Adyghe_NoOCR.txt', 'roman_stats_3_Adyghe_NoOCR.txt')

analyze_file('2_Kabardian_OCR.txt', 'roman_stats_3_Kabardian_OCR.txt')
analyze_file('2_Kabardian_NoOCR.txt', 'roman_stats_3_Kabardian_NoOCR.txt')
# Out:
# Анализ сохранён: roman_stats_3_Adyghe_OCR.txt
# Анализ сохранён: roman_stats_3_Adyghe_NoOCR.txt
# Анализ сохранён: roman_stats_3_Kabardian_OCR.txt
# Анализ сохранён: roman_stats_3_Kabardian_NoOCR.txt

# %% [markdown]
# ## Приводим римские цифры к латинице

# %%
import os
import re

cyr_to_lat = {
    'І': 'I',
    'Ӏ': 'I',
    'ӏ': 'i',
    'і': 'i',
    'Х': 'X',
    'С': 'C',
    'М': 'M',
    'х': 'x',
    'с': 'c',
    'м': 'm',
    'Ι': 'I',  # греческая заглавная йота U+0399
    'ι': 'i',  # греческая строчная йота U+03B9
    'Χ': 'X',  # греческая заглавная хи U+03A7
    'χ': 'x',  # греческая строчная хи U+03C7
}

roman_unicode_map = {
    'Ⅰ':'I','Ⅱ':'II','Ⅲ':'III','Ⅳ':'IV','Ⅴ':'V','Ⅵ':'VI','Ⅶ':'VII','Ⅷ':'VIII','Ⅸ':'IX','Ⅹ':'X',
    'Ⅺ':'XI','Ⅻ':'XII','Ⅼ':'L','Ⅽ':'C','Ⅾ':'D','Ⅿ':'M',
    'ⅰ':'i','ⅱ':'ii','ⅲ':'iii','ⅳ':'iv','ⅴ':'v','ⅵ':'vi','ⅶ':'vii','ⅷ':'viii','ⅸ':'ix','ⅹ':'x',
    'ⅺ':'xi','ⅻ':'xii','ⅼ':'l','ⅽ':'c','ⅾ':'d','ⅿ':'m'
}

ROMAN_LATIN = (
    r'M{0,4}'
    r'(?:CM|CD|D?C{0,3})'
    r'(?:XC|XL|L?X{0,3})'
    r'(?:IX|IV|V?I{0,3})'
)

ROMAN_CYR = (
    r'[МMмm]{0,4}'
    r'(?:[СCсc][МMмm]|[СCсc][Dd]|[Dd]?[СCсc]{0,3})'
    r'(?:[ХXхxΧχ][СCсc]|[ХXхxΧχ][Ll]|[Ll]?[ХXхxΧχ]{0,3})'
    r'(?:[ІIӀіiӏΙι][ХXхxΧχ]|[ІIӀіiӏΙι][Vv]|[Vv]?[ІIӀіiӏΙι]{0,3})'
)

STANDALONE_STICKS = r'[ӀІӏі]'

roman_pattern = re.compile(
    rf'(?:(?<=[\s\-\–\—\.\,\;\:\!\?\(\[\<\«\"\'\/])|(?<=^))(?:{ROMAN_CYR}|{ROMAN_LATIN}|{STANDALONE_STICKS}|[ⅠⅡⅢⅣⅤⅥⅦⅧⅨⅩⅪⅫⅬⅭⅮⅯ]+)(?=[\s\-\–\—\.\,\;\:\!\?\)\]\>\»\"\'\/]|$)',
    re.UNICODE | re.MULTILINE
)

def normalize_roman(match):
    word = match.group()
    if word in roman_unicode_map:
        return roman_unicode_map[word]
    result = ""
    for ch in word:
        if ch in cyr_to_lat:
            result += cyr_to_lat[ch]
        else:
            result += ch
    return result.upper()

def normalize_file(input_file, base_dir=BASE_DIR):
    """Нормализация римских цифр в файле с автоматическим именем выхода"""
    input_path = os.path.join(base_dir, input_file)

    if not os.path.exists(input_path):
        print(f"Файл не найден: {input_path}")
        return

    with open(input_path, 'r', encoding='utf-8') as f:
        text = f.read()

    # нормализация
    text_after = roman_pattern.sub(normalize_roman, text)

    base_name = '_'.join(input_file.split('_')[1:])
    output_file = f"3_{base_name}"

    with open(os.path.join(base_dir, output_file), 'w', encoding='utf-8') as f:
        f.write(text_after)

    print(f"Нормализация завершена: {input_file} -> {output_file}")

# %%
normalize_file('2_Adyghe_OCR.txt')
normalize_file('2_Adyghe_NoOCR.txt')

normalize_file('2_Kabardian_OCR.txt')
normalize_file('2_Kabardian_NoOCR.txt')
# Out:
# Нормализация завершена: 2_Adyghe_OCR.txt -> 3_Adyghe_OCR.txt
# Нормализация завершена: 2_Adyghe_NoOCR.txt -> 3_Adyghe_NoOCR.txt
# Нормализация завершена: 2_Kabardian_OCR.txt -> 3_Kabardian_OCR.txt
# Нормализация завершена: 2_Kabardian_NoOCR.txt -> 3_Kabardian_NoOCR.txt

# %% [markdown]
# ## Stage 4

# %% [markdown]
# ## Считаем смешанные слова (кириллица + латиница) и чисто кириллические + I.

# %%
def calculate_mixed_percentage(file_path, output_suffix='', base_dir=BASE_DIR):
    """Подсчет смешанных слов (кириллица + латиница кроме I)"""
    full_path = os.path.join(base_dir, file_path)

    if not os.path.exists(full_path):
        print(f"Файл не найден: {full_path}")
        return

    try:
        with open(full_path, 'r', encoding='utf-8') as f:
            text = f.read()
    except Exception as e:
        print(f"Ошибка при чтении {file_path}: {e}")
        return

    allowed_latin = {'I'}
    words = re.findall(r'\w+', text)

    pure_cyrillic_words = []
    mixed_words = []

    for word in words:
        if len(word) <= 1:
            continue

        has_cyrillic = False
        has_forbidden_latin = False

        for char in word:
            u_name = unicodedata.name(char, '')

            if 'CYRILLIC' in u_name:
                has_cyrillic = True
            elif 'LATIN' in u_name:
                if char not in allowed_latin:
                    has_forbidden_latin = True

        if has_cyrillic:
            if has_forbidden_latin:
                mixed_words.append(word)
            else:
                pure_cyrillic_words.append(word)

    pure_cyrillic_count = len(pure_cyrillic_words)
    mixed_count = len(mixed_words)

    output_file = os.path.join(base_dir, f'mixed_words{output_suffix}.txt')
    try:
        with open(output_file, 'w', encoding='utf-8') as f:
            for word in mixed_words:
                f.write(word + '\n')
        print(f"✓ Смешанные слова сохранены в: mixed_words{output_suffix}.txt")
    except Exception as e:
        print(f"Ошибка при сохранении: {e}")

    stats_text = [
        f"\n=== СТАТИСТИКА ДЛЯ {file_path} ===",
        f"(Кириллица + I): {pure_cyrillic_count}",
        f"Смешанных (Кириллица + иная латиница): {mixed_count}"
    ]

    total = pure_cyrillic_count + mixed_count
    if total > 0:
        stats_text.append(f"Процент «грязных» слов: {(mixed_count / total) * 100:.5f}%")

    if mixed_words:
        stats_text.append("\n=== ПРИМЕРЫ СМЕШАННЫХ (первые 10) ===")
        stats_text.extend(mixed_words[:10])

    stats_text.append("\n" + "="*60)

    print("\n".join(stats_text))

    stats_file = os.path.join(base_dir, f'stats{output_suffix}.txt')
    try:
        with open(stats_file, 'w', encoding='utf-8') as f:
            f.write("\n".join(stats_text))
        print(f"Статистика сохранена в: stats{output_suffix}.txt")
    except Exception as e:
        print(f"Ошибка при сохранении статистики: {e}")

# %%
calculate_mixed_percentage('3_Adyghe_OCR.txt', '_4_Adyghe_OCR')
calculate_mixed_percentage('3_Adyghe_NoOCR.txt', '_4_Adyghe_NoOCR')

calculate_mixed_percentage('3_Kabardian_OCR.txt', '_4_Kabardian_OCR')
calculate_mixed_percentage('3_Kabardian_NoOCR.txt', '_4_Kabardian_NoOCR')
# Out:
# ✓ Смешанные слова сохранены в: mixed_words_4_Adyghe_OCR.txt
#
# === СТАТИСТИКА ДЛЯ 3_Adyghe_OCR.txt ===
# (Кириллица + I): 10690047
# Смешанных (Кириллица + иная латиница): 388
# Процент «грязных» слов: 0.00363%
#
# === ПРИМЕРЫ СМЕШАННЫХ (первые 10) ===
# Аҧсшəа
# АDZAHA
# адыгэa
# адзыхэa
# адыгэa
# адыгэa
# Кuzey
# Aхэмэ
# Mоу
# OгушIуа
#
# ...
# Статистика сохранена в: stats_4_Adyghe_OCR.txt
# ✓ Смешанные слова сохранены в: mixed_words_4_Adyghe_NoOCR.txt
#
# === СТАТИСТИКА ДЛЯ 3_Adyghe_NoOCR.txt ===
# (Кириллица + I): 10607055
# Смешанных (Кириллица + иная латиница): 387
# Процент «грязных» слов: 0.00365%
#
# === ПРИМЕРЫ СМЕШАННЫХ (первые 10) ===
# Аҧсшəа
# АDZAHA
# адыгэa
# адзыхэa
# адыгэa
# адыгэa
# Кuzey
# Aхэмэ
# Mоу
# OгушIуа
#
# ...
# Статистика сохранена в: stats_4_Adyghe_NoOCR.txt
# ✓ Смешанные слова сохранены в: mixed_words_4_Kabardian_OCR.txt
#
# === СТАТИСТИКА ДЛЯ 3_Kabardian_OCR.txt ===
# (Кириллица + I): 30350407
# Смешанных (Кириллица + иная латиница): 180150
# ...

# %% [markdown]
# ## Удаление смешанных слов

# %%
import os
import re
from tqdm import tqdm

def remove_mixed_words_from_file(original_file, mixed_words_file, base_dir=BASE_DIR):
    """
    Быстро удаляет смешанные слова из файла (построчно + set),
    автоматически создаёт выходной файл с префиксом '4_'
    """
    original_path = os.path.join(base_dir, original_file)
    mixed_path = os.path.join(base_dir, mixed_words_file)

    if not os.path.exists(original_path):
        print(f"Оригинальный файл '{original_file}' не найден!")
        return
    if not os.path.exists(mixed_path):
        print(f"Файл со списком смешанных слов '{mixed_words_file}' не найден!")
        return

    base_name = '_'.join(original_file.split('_')[1:])
    output_file = f"4_{base_name}"
    output_path = os.path.join(base_dir, output_file)

    print(f"Читаем {mixed_words_file}...")
    try:
        with open(mixed_path, 'r', encoding='utf-8') as f:
            mixed_words = set(line.strip() for line in f if line.strip())
        print(f"Уникальных слов для удаления: {len(mixed_words)}")
    except Exception as e:
        print(f"Ошибка при чтении {mixed_words_file}: {e}")
        return

    removed_total = 0
    line_count = 0

    print(f"Читаем и очищаем {original_file} построчно...")
    try:
        with open(original_path, 'r', encoding='utf-8') as infile, \
             open(output_path, 'w', encoding='utf-8') as outfile:

            for line in tqdm(infile, desc="Обработка строк"):
                line_count += 1
                words = re.findall(r'\w+', line, flags=re.UNICODE)

                new_line = ""
                pos = 0
                for word in words:
                    start = line.find(word, pos)
                    end = start + len(word)
                    new_line += line[pos:start]
                    if word not in mixed_words:
                        new_line += word
                    else:
                        removed_total += 1
                    pos = end
                new_line += line[pos:]
                outfile.write(new_line)

        print(f"Очищенный текст сохранён в {output_file}")
        print(f"Всего строк обработано: {line_count}")
        print(f"Удалено слов: {removed_total}\n")

    except Exception as e:
        print(f"Ошибка при обработке {original_file}: {e}")

# %%
remove_mixed_words_from_file('3_Adyghe_OCR.txt', 'mixed_words_4_Adyghe_OCR.txt')
remove_mixed_words_from_file('3_Adyghe_NoOCR.txt', 'mixed_words_4_Adyghe_NoOCR.txt')

remove_mixed_words_from_file('3_Kabardian_OCR.txt', 'mixed_words_4_Kabardian_OCR.txt')
remove_mixed_words_from_file('3_Kabardian_NoOCR.txt', 'mixed_words_4_Kabardian_NoOCR.txt')
# Out:
# Читаем mixed_words_4_Adyghe_OCR.txt...
# Уникальных слов для удаления: 294
# Читаем и очищаем 3_Adyghe_OCR.txt построчно...
# Обработка строк: 1it [00:24, 24.72s/it]
# Очищенный текст сохранён в 4_Adyghe_OCR.txt
# Всего строк обработано: 1
# Удалено слов: 388
#
# Читаем mixed_words_4_Adyghe_NoOCR.txt...
# Уникальных слов для удаления: 293
# Читаем и очищаем 3_Adyghe_NoOCR.txt построчно...
# Обработка строк: 1it [00:20, 20.68s/it]
# Очищенный текст сохранён в 4_Adyghe_NoOCR.txt
# Всего строк обработано: 1
# Удалено слов: 387
#
# Читаем mixed_words_4_Kabardian_OCR.txt...
# Уникальных слов для удаления: 91969
# Читаем и очищаем 3_Kabardian_OCR.txt построчно...
# Обработка строк: 1it [01:09, 69.94s/it]
# Очищенный текст сохранён в 4_Kabardian_OCR.txt
# Всего строк обработано: 1
# Удалено слов: 180150
#
# Читаем mixed_words_4_Kabardian_NoOCR.txt...
# Уникальных слов для удаления: 14720
# Читаем и очищаем 3_Kabardian_NoOCR.txt построчно...
# Обработка строк: 1it [02:08, 128.45s/it]
# ...

# %% [markdown]
# # Stage 5 (Normalize sticks)

# %%
import os
import re
import unicodedata

sticks = {
    'I', 'l', 'ı',          # латинские
    'І', 'і', 'ӏ', 'Ӏ',     # кириллические
    'Ι', 'ι',                # греческие
    '1', '!', '¦', 'ا', '！' # прочие
}

# Только кириллика + палочки без !
_CYR = r'\u0400-\u04FF'
_STICKS_NO_EXCL = r'IІіӀӏ¦ıΙι1lا！'
_ANY = f'[{_CYR}{_STICKS_NO_EXCL}]'

# ! только в начале/середине, не в конце
WORD_PATTERN = rf'!?(?:[{_CYR}{_STICKS_NO_EXCL}!]*{_ANY})'

def is_cyrillic_word(word):
    has_cyrillic = False
    for ch in word:
        if ch in sticks:
            continue
        if 'CYRILLIC' not in unicodedata.name(ch, ''):
            return False
        has_cyrillic = True
    return has_cyrillic

def count_sticks(text):
    stats = {k: 0 for k in sticks}
    for word in re.findall(WORD_PATTERN, text, flags=re.UNICODE):
        if not is_cyrillic_word(word):
            continue
        for ch in word:
            if ch in stats:
                stats[ch] += 1
    return stats

def analyze_and_fix_sticks(input_file, base_dir=BASE_DIR):
    input_path = os.path.join(base_dir, input_file)
    if not os.path.exists(input_path):
        print(f"Файл не найден: {input_path}")
        return

    with open(input_path, 'r', encoding='utf-8') as f:
        text = f.read()

    stats_before = count_sticks(text)

    def replace(match):
        word = match.group()
        if not is_cyrillic_word(word):
            return word
        result = []
        for ch in word:
            if ch in sticks:
                result.append('I')
            else:
                result.append(ch)
        return ''.join(result)

    text_after = re.sub(WORD_PATTERN, replace, text, flags=re.UNICODE)

    stats_after = count_sticks(text_after)

    stats_filename = f"sticks_stats_{input_file}.txt"
    stats_path = os.path.join(base_dir, stats_filename)

    total_before = sum(stats_before.values())
    total_after = sum(stats_after.values())

    with open(stats_path, 'w', encoding='utf-8') as f:
        f.write("СТАТИСТИКА ПАЛОЧЕК ДО → ПОСЛЕ\n")
        f.write("=" * 40 + "\n")
        for k in sorted(sticks):
            b = stats_before.get(k, 0)
            a = stats_after.get(k, 0)
            f.write(f"{k:>2}: {b:,} → {a:,}  ({a - b:+,})\n")
        f.write("-" * 40 + "\n")
        f.write(f"ВСЕГО: {total_before:,} → {total_after:,}\n")

    print(f"\nСТАТИСТИКА сохранена: {stats_filename}")
    print("\nДетали:")
    for k in sorted(sticks):
        b = stats_before.get(k, 0)
        a = stats_after.get(k, 0)
        print(f"{k:>2}: {b:,} → {a:,}  ({a - b:+,})")
    print(f"ВСЕГО: {total_before:,} → {total_after:,}")

    base_name = '_'.join(input_file.split('_')[1:])
    output_file = f"5_{base_name}"
    with open(os.path.join(base_dir, output_file), 'w', encoding='utf-8') as f:
        f.write(text_after)

    print(f"\nФайл с исправленным текстом сохранён: {output_file}")

# %%
analyze_and_fix_sticks('4_Adyghe_OCR.txt')
analyze_and_fix_sticks('4_Adyghe_NoOCR.txt')

analyze_and_fix_sticks('4_Kabardian_OCR.txt')
analyze_and_fix_sticks('4_Kabardian_NoOCR.txt')
# Out:
# СТАТИСТИКА сохранена: sticks_stats_4_Adyghe_OCR.txt.txt
#
# Детали:
#  !: 16 → 0  (-16)
#  1: 233 → 0  (-233)
#  I: 3,877,781 → 3,885,331  (+7,550)
#  l: 0 → 0  (+0)
#  ¦: 0 → 0  (+0)
#  ı: 0 → 0  (+0)
#  Ι: 0 → 0  (+0)
#  ι: 0 → 0  (+0)
#  І: 7,301 → 0  (-7,301)
#  і: 0 → 0  (+0)
#  Ӏ: 0 → 0  (+0)
#  ӏ: 0 → 0  (+0)
#  ا: 0 → 0  (+0)
#  ！: 0 → 0  (+0)
# ВСЕГО: 3,885,331 → 3,885,331
#
# Файл с исправленным текстом сохранён: 5_Adyghe_OCR.txt
#
# СТАТИСТИКА сохранена: sticks_stats_4_Adyghe_NoOCR.txt.txt
#
# Детали:
#  !: 15 → 0  (-15)
#  1: 188 → 0  (-188)
#  I: 3,847,896 → 3,855,400  (+7,504)
#  l: 0 → 0  (+0)
#  ¦: 0 → 0  (+0)
#  ı: 0 → 0  (+0)
#  Ι: 0 → 0  (+0)
#  ι: 0 → 0  (+0)
#  І: 7,301 → 0  (-7,301)
#  і: 0 → 0  (+0)
#  Ӏ: 0 → 0  (+0)
#  ӏ: 0 → 0  (+0)
#  ا: 0 → 0  (+0)
#  ！: 0 → 0  (+0)
# ВСЕГО: 3,855,400 → 3,855,400
#
# Файл с исправленным текстом сохранён: 5_Adyghe_NoOCR.txt
#
# СТАТИСТИКА сохранена: sticks_stats_4_Kabardian_OCR.txt.txt
#
# Детали:
#  !: 2,914 → 0  (-2,914)
# ...
